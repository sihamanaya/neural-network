# %% [markdown]
# <a href="https://colab.research.google.com/github/sihamanaya/neural-network/blob/main/assignment_work_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

df = pd.read_csv ('/content/ce889_dataCollection.csv')
df = pd.read_excel('/content/Libro2.xlsx')
columns= ['x_position', 'y_position','x_speed', 'y_speed']
df.columns = columns

# %%
df.head()
# Out:
#    x_position  y_position  x_speed  y_speed
# 0           2           9       31       14
# 1           3           1       12       17
# 2           4          10        3       12
